# %%
# Import dependencies for pandas (read in the CSV) and create engine from sqlalchemy to set up our database
import pandas as pd
from sqlalchemy import create_engine
import codecs
import requests
import json
from pprint import pprint
from config import api_key

# %%
# Import episodes csv using the pandas read_csv function, display dataframe head to get a quick look at the data
episodes_file = "episodes.csv"
episodes_df = pd.read_csv(episodes_file)
episodes_df.head()
# Out:
#                                                title  \
# 0                                Piątek - 01 grudnia
# 1                                Sobota - 02 grudnia
# 2                             Niedziela - 03 grudnia
# 3                               Introduction to Luke
# 4  Dear Science: Lightning, Dead Cats and Hand Sa...
#
#                                                audio  audio_length  \
# 0  https://cdneu.modlitwawdrodze.pl/prayers/MWD_2...           490
# 1  https://cdneu.modlitwawdrodze.pl/prayers/MWD_2...           481
# 2  https://cdneu.modlitwawdrodze.pl/prayers/MWD_2...           667
# 3  http://www.wgcr.net/images/TimelessTruths/TTT-...          1691
# 4  http://95bfm.com/sites/default/files/291117_De...          1152
#
#                                          description                pub_date  \
# 0  święci męczennicy jezuiccy Edmund Campion SJ, ...  2017-12-01 00:00:00+00
# 1       bł. Rafał Chyliński, prezbiter, Łk 21, 34-36  2017-12-02 00:00:00+00
# 2           Pierwsza Niedziela Adwentu, Mk 13, 33-37  2017-12-03 00:00:00+00
# 3                                       Luke 1:1-4 -  2017-12-03 11:30:05+00
# 4  <p>Today on Dear Science with AUT's Allan Blac...  2017-12-27 11:00:00+00
#
#                                uuid                      podcast_uuid
# 0  fd5d891411174c7ca953c1f54657c3eb  811c18cf575841b3bef4601978f17ca9
# 1  5c28fa0a27b342cd92ff03c16a8019c2  811c18cf575841b3bef4601978f17ca9
# 2  efdc9f4f07fa4c4883f8848256066cec  811c18cf575841b3bef4601978f17ca9
# 3  cc2860165fa84d1092f6b45f19255a87  36ed4e62dcd94412a5211cc9bd76ba7c
# 4  69bd409e0469433581ccc76cf7b664ad  fa36a26a1879453f95da1379c737cd6d

# %%
# Import episodes csv using the pandas read_csv function, display dataframe head to get a quick look at the data
# podcast_file = "podcasts.csv"
# podcast_df = pd.read_csv(podcast_file)
# podcast_df.head()

# %% [markdown]
# # Work on episodes.csv

# %%
# Create a filtered episodes dataframe from specific columns 
# Here we are only really interested the eventual primary key (podcast_uuid) and sortable, descriptive columns 
# Filtering out extraneous fields
episodes_cols = ["title", "description", "podcast_uuid", "uuid"]
episodes_transformed = episodes_df[episodes_cols].copy()

# Rename the column headers
episodes_transformed = episodes_transformed.rename(columns={"title": "title", 
                                                            "description": "description",
                                                            "uuid": "episode_id",
                                                          "podcast_uuid": "podcast_id"})

# Clean the data by dropping duplicates and setting the index
# Display the head of our new dataframe
episodes_transformed.drop_duplicates("episode_id", inplace=True)
episodes_transformed.set_index("episode_id", inplace=True)

episodes_transformed.head()
# Out:
#                                                                               title  \
# episode_id
# fd5d891411174c7ca953c1f54657c3eb                                Piątek - 01 grudnia
# 5c28fa0a27b342cd92ff03c16a8019c2                                Sobota - 02 grudnia
# efdc9f4f07fa4c4883f8848256066cec                             Niedziela - 03 grudnia
# cc2860165fa84d1092f6b45f19255a87                               Introduction to Luke
# 69bd409e0469433581ccc76cf7b664ad  Dear Science: Lightning, Dead Cats and Hand Sa...
#
#                                                                         description  \
# episode_id
# fd5d891411174c7ca953c1f54657c3eb  święci męczennicy jezuiccy Edmund Campion SJ, ...
# 5c28fa0a27b342cd92ff03c16a8019c2       bł. Rafał Chyliński, prezbiter, Łk 21, 34-36
# efdc9f4f07fa4c4883f8848256066cec           Pierwsza Niedziela Adwentu, Mk 13, 33-37
# cc2860165fa84d1092f6b45f19255a87                                       Luke 1:1-4 -
# 69bd409e0469433581ccc76cf7b664ad  <p>Today on Dear Science with AUT's Allan Blac...
#
#                                                         podcast_id
# episode_id
# fd5d891411174c7ca953c1f54657c3eb  811c18cf575841b3bef4601978f17ca9
# 5c28fa0a27b342cd92ff03c16a8019c2  811c18cf575841b3bef4601978f17ca9
# efdc9f4f07fa4c4883f8848256066cec  811c18cf575841b3bef4601978f17ca9
# cc2860165fa84d1092f6b45f19255a87  36ed4e62dcd94412a5211cc9bd76ba7c
# 69bd409e0469433581ccc76cf7b664ad  fa36a26a1879453f95da1379c737cd6d

# %%
# Drop NA values
episodes_final = episodes_transformed.dropna()

episodes_final.head()
# Out:
#                                                                               title  \
# episode_id
# fd5d891411174c7ca953c1f54657c3eb                                Piątek - 01 grudnia
# 5c28fa0a27b342cd92ff03c16a8019c2                                Sobota - 02 grudnia
# efdc9f4f07fa4c4883f8848256066cec                             Niedziela - 03 grudnia
# cc2860165fa84d1092f6b45f19255a87                               Introduction to Luke
# 69bd409e0469433581ccc76cf7b664ad  Dear Science: Lightning, Dead Cats and Hand Sa...
#
#                                                                         description  \
# episode_id
# fd5d891411174c7ca953c1f54657c3eb  święci męczennicy jezuiccy Edmund Campion SJ, ...
# 5c28fa0a27b342cd92ff03c16a8019c2       bł. Rafał Chyliński, prezbiter, Łk 21, 34-36
# efdc9f4f07fa4c4883f8848256066cec           Pierwsza Niedziela Adwentu, Mk 13, 33-37
# cc2860165fa84d1092f6b45f19255a87                                       Luke 1:1-4 -
# 69bd409e0469433581ccc76cf7b664ad  <p>Today on Dear Science with AUT's Allan Blac...
#
#                                                         podcast_id
# episode_id
# fd5d891411174c7ca953c1f54657c3eb  811c18cf575841b3bef4601978f17ca9
# 5c28fa0a27b342cd92ff03c16a8019c2  811c18cf575841b3bef4601978f17ca9
# efdc9f4f07fa4c4883f8848256066cec  811c18cf575841b3bef4601978f17ca9
# cc2860165fa84d1092f6b45f19255a87  36ed4e62dcd94412a5211cc9bd76ba7c
# 69bd409e0469433581ccc76cf7b664ad  fa36a26a1879453f95da1379c737cd6d

# %%
# Sort the data by titles
episodes_final_sorted = episodes_final.sort_values(by=['title'], ascending = True)

episodes_final_sorted.head()
# Out:
#                                                                            title  \
# episode_id
# 07e2cd89a7244383a6c8fb8520676f5b     ! Episode 1: Too-Good-For-Human-Form Tobias
# 9a5405870f8e4a21a39f8c55a5b098c3               ! GRACIAS A VOSOTROS ! FELIZ 2018
# f1b75bb5e12b49e394cae03d398ff2a0               ! GRACIAS A VOSOTROS ! FELIZ 2018
# 380313c52ca046aab62177a06fc7615e  !!!!!!!!FREE DOWNLOAD SIMPLE !!!!!!!!!!!!!!!!!
# fe4c70f40fd64fefba3c2764ebc59b14  !!Special Announcement!! & Short Interview Mix
#
#                                                                         description  \
# episode_id
# 07e2cd89a7244383a6c8fb8520676f5b  <p>This week our hosts dive hawk-first into th...
# 9a5405870f8e4a21a39f8c55a5b098c3                                   GRACIAS A TODOS.
# f1b75bb5e12b49e394cae03d398ff2a0                                   GRACIAS A TODOS.
# 380313c52ca046aab62177a06fc7615e  !!!!!!!!FREE DOWNLOAD SIMPLE !!!!!!!!!!!!!!!!!...
# fe4c70f40fd64fefba3c2764ebc59b14  <p><img class="size-medium wp-image-723 alignl...
#
#                                                         podcast_id
# episode_id
# 07e2cd89a7244383a6c8fb8520676f5b  584c7d1e2208418d9ec0efea10197ad6
# 9a5405870f8e4a21a39f8c55a5b098c3  fc31d46e3e464e9ca043ac1a61e0747d
# f1b75bb5e12b49e394cae03d398ff2a0  1bd453973e764a19933fcfa62d3c1678
# 380313c52ca046aab62177a06fc7615e  64101a4a5eb54f47afa3a7120a4d32db
# fe4c70f40fd64fefba3c2764ebc59b14  d86b2ff8c4084bb4857398e5856a9d25

# %%
# Testing for case sensitivity
episode_find = episodes_final_sorted.loc[episodes_final_sorted['title'].str.contains('Stranger Things')]

episode_find.head()
# Out:
#                                                                           title  \
# episode_id
# e33741cfbfec4b3194c8087bd9446b1b                       #019 Más Stranger Things
# 081864775e2c4cf1bce56ecc17cc9f0f                       #019 Más Stranger Things
# f6e768d5c9a248829a6766d072d459a8            #039 - Especial “Stranger Things 2”
# cbaa96fd37794cb486406071aecd2586  #10 - Crisis on Earth-X and Stranger Things 2
# be909ceaf8604e1380b0293933cafcf4                         #142 - Stranger Things
#
#                                                                         description  \
# episode_id
# e33741cfbfec4b3194c8087bd9446b1b  <p><strong>SerialMe! 019.</strong> Más Strange...
# 081864775e2c4cf1bce56ecc17cc9f0f  <p><strong>SerialMe! 019.</strong> Más Strange...
# f6e768d5c9a248829a6766d072d459a8  Promessa é dívida! Se toda dívida fosse tão le...
# cbaa96fd37794cb486406071aecd2586  <br />\nWelcome to Culture Pop Remix #10!<br /...
# be909ceaf8604e1380b0293933cafcf4  <img class="thumb-image" alt="142 Stranger Thi...
#
#                                                         podcast_id
# episode_id
# e33741cfbfec4b3194c8087bd9446b1b  c31e82449da64db8b3afdc2d7ba484a9
# 081864775e2c4cf1bce56ecc17cc9f0f  30d4ca6df1884a66874bf764d8332678
# f6e768d5c9a248829a6766d072d459a8  5bc0a4b912704322bf72cdb52dfa996e
# cbaa96fd37794cb486406071aecd2586  769d7995433b483abb290371df034447
# be909ceaf8604e1380b0293933cafcf4  85c2596c25894cbbb2a5b96e75feeb72

# %% [markdown]
# # Work on podcasts.csv

# %%
# # Create a filtered dataframe from specific columns 
# # Here we are only really interested the eventual primary key (uuid) and sortable, descriptive columns 
# # Filtering out extraneous fields
podcast_cols = ["uuid", "title", "language", "categories"]
podcast_clean= podcast_df[podcast_cols].copy()

# # Rename the column headers
podcast_clean = podcast_clean.rename(columns={"uuid": "id"})

# # Clean the data by dropping duplicates and setting the index
# # Display the head of our new dataframe
podcast_clean.drop_duplicates("id", inplace=True)
podcast_clean.set_index("id", inplace=True)

podcast_clean.head()

# %%
# # Our project will focus on the intersection of podcasts and streaming (Netfilx)
# # Display unique values for the categories column and locate what is relevant: "TV & Film"
podcast_clean.categories.unique()

# %%
# # Filter the dataframe to display only results mathing "TV & Film" in the "categories" column
podcast_tvfilm = podcast_clean.loc[podcast_clean['categories'] == 'TV & Film']

# # Sort the data by title
podcast_tvfilm_a = podcast_tvfilm.sort_values(by=['title'], ascending = False)
podcast_tvfilm_a.head()

# %%
# # Filtered the dataframe by English only podcasts, attempting to clean up any errors in loading to mysql
podcast_english = podcast_tvfilm_a.loc[podcast_tvfilm_a['language'] == 'English']

podcast_english.head()

# %%
# # Testing for case sensitivity
podcast_find = podcast_tvfilm_a.loc[podcast_tvfilm_a['title'].str.contains('Stranger Things')]
podcast_find

# %% [markdown]
# # Connect OMDb API

# %%
# Import Netflix_Shows.csv 
file = "netflix_shows_.csv"
netflix_data = pd.read_csv(file)
netflix_data.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
# Select only the 'title' of Netflix tv shows
# Convert series into a list
netflix_titles = list(netflix_data['title'])
netflix_titles[0:5]
# Out:
# ['White Chicks',
#  'Lucky Number Slevin',
#  "Grey's Anatomy",
#  'Prison Break',
#  'How I Met Your Mother']

# %%
# Create empty list of OMDb description responses of netflix titles
responses = []
base_url = f"http://www.omdbapi.com/?apikey={api_key}&t="

# Loop through netflix_titles
# Exclude title '3%' because creates an error with title in API url call
for title in [x for x in netflix_titles if x != '3%']:
    
#   Create request for each title
    omdb_response = requests.get(base_url + title).json()

#   Append omdb_response to main list of responses
    responses.append(omdb_response)

# %%
# Show length of list responses
# Does not include show '3%'
len(responses)
# Out:
# 999

# %%
# Check first 6 responses from OMDb for Netflix Titles
responses[0]
# Out:
# {'Title': 'White Chicks',
#  'Year': '2004',
#  'Rated': 'PG-13',
#  'Released': '23 Jun 2004',
#  'Runtime': '109 min',
#  'Genre': 'Comedy, Crime',
#  'Director': 'Keenen Ivory Wayans',
#  'Writer': 'Keenen Ivory Wayans (screenplay), Shawn Wayans (screenplay), Marlon Wayans (screenplay), Andrew McElfresh (screenplay), Michael Anthony Snowden (screenplay), Xavier Cook (screenplay), Keenen Ivory Wayans (story), Shawn Wayans (story), Marlon Wayans (story)',
#  'Actors': 'Shawn Wayans, Marlon Wayans, Jaime King, Frankie Faison',
#  'Plot': 'Two disgraced FBI agents go way undercover in an effort to protect hotel heiresses the Wilson Sisters from a kidnapping plot.',
#  'Language': 'English',
#  'Country': 'USA',
#  'Awards': '3 wins & 13 nominations.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY3OTg2OTM3OV5BMl5BanBnXkFtZTYwNzY5OTA3._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '15%'},
#   {'Source': 'Metacritic', 'Value': '41/100'}],
#  'Metascore': '41',
#  'imdbRating': '5.5',
#  'imdbVotes': '115,904',
#  'imdbID': 'tt0381707',
#  'Type': 'movie',
#  'DVD': '26 Oct 2004',
#  'BoxOffice': '$69,148,997',
#  'Production': 'Columbia Pictures',
#  'Website': 'http://www.sonypictures.com/movies/whitechicks',
#  'Response': 'True'}

# %%
# Saved 'responses' to a json file
with open('responses.json', 'w') as outfile:
    json.dump(responses, outfile)

# %%
# Use method read_json to convert responses.json to pd DF
all_omdb_categories = pd.read_json("responses.json")

print(f"The length of all_omdb_dategories DF is {len(all_omdb_categories)}")
all_omdb_categories.head()
# Out:
# The length of all_omdb_dategories DF is 999
#                                               Actors  \
# 0  Shawn Wayans, Marlon Wayans, Jaime King, Frank...
# 1  Josh Hartnett, Bruce Willis, Lucy Liu, Morgan ...
# 2  Ellen Pompeo, Justin Chambers, Chandra Wilson,...
# 3  Dominic Purcell, Wentworth Miller, Robert Knep...
# 4  Josh Radnor, Jason Segel, Cobie Smulders, Neil...
#
#                                               Awards    BoxOffice  \
# 0                           3 wins & 13 nominations.  $69,148,997
# 1                            5 wins & 4 nominations.          N/A
# 2  Won 2 Golden Globes. Another 67 wins & 209 nom...          NaN
# 3  Nominated for 2 Golden Globes. Another 4 wins ...          NaN
# 4  Nominated for 2 Golden Globes. Another 25 wins...          NaN
#
#                     Country          DVD             Director Error  \
# 0                       USA  26 Oct 2004  Keenen Ivory Wayans   NaN
# 1  Germany, UK, USA, Canada  26 Sep 2006        Paul McGuigan   NaN
# 2                       USA          NaN                  N/A   NaN
# 3                   UK, USA          NaN                  N/A   NaN
# 4                       USA          NaN                  N/A   NaN
#
#                                      Genre                   Language  \
# 0                            Comedy, Crime                    English
# 1          Crime, Drama, Mystery, Thriller                    English
# 2                           Drama, Romance                    English
# 3  Action, Crime, Drama, Mystery, Thriller           Spanish, English
# 4                          Comedy, Romance  English, Persian, Chinese
#
#   Metascore     ...       Runtime                  Title    Type  \
# 0        41     ...       109 min           White Chicks   movie
# 1        53     ...       110 min    Lucky Number Slevin   movie
# 2       N/A     ...        41 min         Grey's Anatomy  series
# 3       N/A     ...        44 min           Prison Break  series
# 4       N/A     ...        22 min  How I Met Your Mother  series
#
#                                           Website  \
# 0  http://www.sonypictures.com/movies/whitechicks
# 1                                             N/A
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#                                               Writer       Year     imdbID  \
# 0  Keenen Ivory Wayans (screenplay), Shawn Wayans...       2004  tt0381707
# 1                                     Jason Smilovic       2006  tt0425210
# 2                                      Shonda Rhimes      2005–  tt0413573
# 3                                     Paul Scheuring  2005–2017  tt0455275
# 4                          Carter Bays, Craig Thomas  2005–2014  tt0460649
#
#   imdbRating imdbVotes totalSeasons
# 0        5.5   115,904          NaN
# 1        7.8   285,907          NaN
# 2        7.6   205,650           15
# 3        8.4   421,553            5
# 4        8.3   527,514            9
#
# [5 rows x 27 columns]

# %%
# Edit all_omdb_dategories to choose select categories
netflix_omdb_key_categories = all_omdb_categories.filter(['Title','Type',
                                                  'Genre', 'imdbRating',
                                                  'imdbID','Language',
                                                  'Country','totalSeasons'], axis=1)
netflix_omdb_key_categories.head()

nf = netflix_omdb_key_categories.sort_values(by=['imdbRating'], ascending = False)
nf.head(100)

df = nf[nf.imdbRating != "N/A"]


top_five_shows = df.drop_duplicates(subset='Title', keep="last").copy()[0:5]
top_five_shows
# Out:
#                         Title    Type  \
# 6                Breaking Bad  series
# 418                  Sherlock  series
# 12                 Death Note  series
# 83            Stranger Things  series
# 557  Justice League Unlimited  series
#
#                                                  Genre imdbRating     imdbID  \
# 6                               Crime, Drama, Thriller        9.5  tt0903747
# 418                    Crime, Drama, Mystery, Thriller        9.2  tt1475582
# 12   Animation, Crime, Drama, Fantasy, Mystery, Thr...        9.0  tt0877057
# 83   Drama, Fantasy, Horror, Mystery, Sci-Fi, Thriller        8.9  tt4574334
# 557                       Animation, Action, Adventure        8.9  tt6025022
#
#              Language  Country totalSeasons
# 6    English, Spanish      USA            5
# 418           English  UK, USA            4
# 12           Japanese    Japan            1
# 83            English      USA            3
# 557           English      USA            2

# %%
#Loop

matched_netflix_titles = []

for ep_desc in episodes_final['description']:
    for title in netflix_titles:
        match = str(ep_desc).find(title)
        if match == -1:
            matched_netflix_titles.append(title)
matched_netflix_titles
# Out:
# ['White Chicks',
#  'Lucky Number Slevin',
#  "Grey's Anatomy",
#  'Prison Break',
#  'How I Met Your Mother',
#  'Supernatural',
#  'Breaking Bad',
#  'The Vampire Diaries',
#  'The Walking Dead',
#  'Pretty Little Liars',
#  'Once Upon a Time',
#  'Sherlock',
#  'Death Note',
#  'Naruto',
#  'The Hunter',
#  'Lottie Dottie Chicken',
#  'Arrow',
#  'Black Mirror',
#  'The Originals',
#  'The 100',
#  'Masha and the Bear',
#  'ÌÒ Pai, ÌÒ - Look at This',
#  'Nymphomaniac: Volume 1',
#  'Hunter X Hunter (2011)',
#  "Marvel's Luke Cage",
#  "Marvel's Iron Fist",
#  'Narcos',
#  'The Flash',
#  'The Seven Deadly Sins',
#  'Scream',
#  'The Do-Over',
#  'OperaÌ_Ìµes Especiais',
#  '3%',
#  'Trollhunters',
#  'Fearless',
#  'Hyena Road',
#  'Santa Clarita Diet',
#  'Sex, Love and Therapy',
#  'White Girl',
#  'Girlboss',
#  'City of God: 10 Years Later',
#  '13 Reasons Why',
#  'Sand Castle',
#  'Salvador Martinha - Tip of the Tongue',
#  'Sandy Wexler',
#  'O Amor no DivÌ£',
#  'Stronger Than the World',
#  'Back and Forth',
#  'Happily Married',
#  'Pandora',
#  'Lucky Number Slevin',
#  'The Office (U.S.)',
#  "Grey's Anatomy",
#  'Prison Break',
#  '90210',
#  'Gossip Girl',
#  'How I Met Your Mother',
#  'Supernatural',
#  'Breaking Bad',
#  'Parks and Recreation',
#  'Glee',
#  'The Vampire Diaries',
#  'Family Guy',
#  'Criminal Minds',
#  'Friends',
#  'The Secret Life of the American Teenager',
#  'One Tree Hill',
#  'The Walking Dead',
#  'Pretty Little Liars',
#  'Shameless (U.S.)',
#  'New Girl',
#  'American Horror Story',
#  'Orange Is the New Black',
#  "Inside Russia's Toughest Prison",
#  'Black Mirror',
#  'Bates Motel',
#  'The 100',
#  "Marvel's Iron Fist",
#  'Grace and Frankie',
#  'How to Get Away with Murder',
#  'The Get Down',
#  'Love',
#  'The Flash',
#  'The OA',
#  'Stranger Things',
#  'Ingobernable',
#  'Zootopia',
#  'Meet the Blacks',
#  'Finding Dory',
#  'Santa Clarita Diet',
#  'Sausage Party',
#  "Pete's Dragon",
#  'Kevin Hart: What Now?',
#  'Girlboss',
#  'The Discovery',
#  'Sand Castle',
#  'Sandy Wexler',
#  'Chewing Gum',
#  'Cheer Squad',
#  'Only for One Night',
#  'The Life Aquatic with Steve Zissou',
#  'Lucky Number Slevin',
#  'The L Word',
#  'The Office (U.S.)',
#  '30 Rock',
#  'Mad Men',
#  "It's Always Sunny in Philadelphia",
#  'Californication',
#  'Parks and Recreation',
#  'Friends',
#  'Shameless (U.S.)',
#  'Portlandia',
#  'New Girl',
#  "Don't Trust the B---- in Apartment 23",
#  'Friends with Benefits',
#  'The Client List',
#  'Halt and Catch Fire',
#  '5 to 7',
#  "Marvel's Iron Fist",
#  "Chef's Table",
#  'Documentary Now!',
#  'Grace and Frankie',
#  'Better Call Saul',
#  'The Get Down',
#  "Schitt's Creek",
#  'Lovesick',
#  'Flaked',
#  'Master of None',
#  'Chelsea',
#  'Abstract: The Art of Design',
#  "Cooper Barrett's Guide to Surviving Life",
#  'The Great British Baking Show',
#  'Life in Pieces',
#  'Crazy Ex-Girlfriend',
#  'Easy',
#  'Santa Clarita Diet',
#  'No Tomorrow',
#  'Minimalism: A Documentary About the Important Things',
#  'Girlboss',
#  'Hot Girls Wanted: Turned On',
#  'The Discovery',
#  '13 Reasons Why',
#  'Sandy Wexler',
#  'Chewing Gum',
#  'Win It All',
#  'MerlÌ?',
#  'Amy Schumer: The Leather Special',
#  'Louis C.K. 2017',
#  'Dave Chappelle',
#  'Almost Adults',
#  'The Brothers',
#  'Skins',
#  'The Cleveland Show',
#  'Absolutely Fabulous',
#  "Don't Trust the B---- in Apartment 23",
#  'Raising Hope',
#  'Come Fly With Me',
#  'Orange Is the New Black',
#  'Brickleberry',
#  'Bates Motel',
#  'BoJack Horseman',
#  'Being Mary Jane: The Series',
#  'Documentary Now!',
#  'Grace and Frankie',
#  'Unbreakable Kimmy Schmidt',
#  'The Get Down',
#  'Love',
#  'Bordertown',
#  'Jane The Virgin',
#  "Schitt's Creek",
#  'Dope',
#  'Lovesick',
#  'The Carmichael Show',
#  "Cooper Barrett's Guide to Surviving Life",
#  'The Great British Baking Show',
#  'November Rule',
#  'Life in Pieces',
#  'Crazy Ex-Girlfriend',
#  'Easy',
#  'Haters Back Off',
#  'Kubo and the Two Strings',
#  'Skins',
#  'A Weekend with the Family',
#  'Crazyhead',
#  'Queen of Katwe',
#  'Little Boxes',
#  'Deidra & Laney Rob a Train',
#  'Girlboss',
#  'Hot Girls Wanted: Turned On',
#  '13 Reasons Why',
#  'Hurricane Bianca',
#  'Honeytrap',
#  'Greenleaf',
#  'Lazy Eye',
#  'Like Cotton Twines',
#  'The Wedding Party',
#  'Dave Chappelle',
#  'Only for One Night',
#  'Boy Bye',
#  'Almost Adults',
#  'Nancy Drew',
#  '30 Rock',
#  'Nurse Jackie',
#  'Parks and Recreation',
#  'Drop Dead Diva',
#  'Gilmore Girls',
#  'Parenthood',
#  'Life Unexpected',
#  'Portlandia',
#  'New Girl',
#  "Don't Trust the B---- in Apartment 23",
#  'Raising Hope',
#  'Being Human (U.S.)',
#  'Friends with Benefits',
#  'The Carrie Diaries',
#  'Baby Daddy',
#  'Halt and Catch Fire',
#  'The Angriest Man in Brooklyn',
#  '5 to 7',
#  "Chef's Table",
#  'Grace and Frankie',
#  'Unbreakable Kimmy Schmidt',
#  'The Get Down',
#  'Sense8',
#  'Love',
#  'Bordertown',
#  "Girlfriends' Guide to Divorce",
#  "Schitt's Creek",
#  'The Carmichael Show',
#  'Chelsea',
#  'Abstract: The Art of Design',
#  "Cooper Barrett's Guide to Surviving Life",
#  'The Great British Baking Show',
#  'Life in Pieces',
#  'Crazy Ex-Girlfriend',
#  'Fried',
#  'The Great Gilly Hopkins',
#  'The Magicians',
#  'One Day at a Time',
#  'No Tomorrow',
#  'Hot Girls Wanted: Turned On',
#  '13 Reasons Why',
#  'Better Off Single',
#  'Sandy Wexler',
#  'Chewing Gum',
#  'The Matchbreaker',
#  'Tramps',
#  'Slam',
#  'Cheer Squad',
#  'Almost Adults',
#  'The Waterboy',
#  '10 Things I Hate About You',
#  'Grease',
#  'How to Lose a Guy in 10 Days',
#  'The Benchwarmers',
#  'Step Up',
#  'High School Musical 2',
#  'Twilight',
#  'Coraline',
#  'Hannah Montana: The Movie',
#  'The Office (U.S.)',
#  'Friday Night Lights',
#  'StarStruck',
#  "Grey's Anatomy",
#  'Prison Break',
#  '90210',
#  'Gossip Girl',
#  'How I Met Your Mother',
#  'Glee',
#  'The Vampire Diaries',
#  'Family Guy',
#  'Criminal Minds',
#  'Friends',
#  'Mean Girls 2',
#  'The Secret Life of the American Teenager',
#  "That '70s Show",
#  'Gilmore Girls',
#  'Parenthood',
#  'Heartland',
#  'Pretty Little Liars',
#  'Shameless (U.S.)',
#  'Switched at Birth',
#  'New Girl',
#  'Hart of Dixie',
#  'The Client List',
#  'The Carrie Diaries',
#  'Safe Haven',
#  'Baby Daddy',
#  'The Night Shift',
#  'Reign',
#  'Grace and Frankie',
#  'How to Get Away with Murder',
#  'Fuller House',
#  'Finding Dory',
#  'Gilmore Girls: A Year in the Life',
#  '13 Reasons Why',
#  'Gabriel lglesias: I‰Ûªm Sorry For What I Said When I Was Hungry',
#  'Amy Schumer: The Leather Special',
#  'Cheer Squad',
#  'Dave Chappelle',
#  'The Waterboy',
#  'Grease',
#  'The Wedding Planner',
#  'Blow',
#  'High School Musical',
#  'High School Musical 2',
#  'Twilight',
#  'Hannah Montana: The Movie',
#  'The Office (U.S.)',
#  'Bones',
#  'Law & Order: Special Victims Unit',
#  'Prison Break',
#  'Nurse Jackie',
#  'NCIS',
#  'Gossip Girl',
#  'How I Met Your Mother',
#  'Supernatural',
#  'Parks and Recreation',
#  'Glee',
#  'The Vampire Diaries',
#  'Criminal Minds',
#  'Friends',
#  'Mean Girls 2',
#  'The Secret Life of the American Teenager',
#  'One Tree Hill',
#  'Army Wives',
#  'Gilmore Girls',
#  'Private Practice',
#  'Parenthood',
#  'Pretty Little Liars',
#  'Shameless (U.S.)',
#  'New Girl',
#  'Revenge',
#  'Scandal',
#  'Magic Mike',
#  'Trouble with the Curve',
#  'Orange Is the New Black',
#  'Baby Daddy',
#  'The Night Shift',
#  'The Originals',
#  'Home',
#  'How to Get Away with Murder',
#  'Zootopia',
#  'Finding Dory',
#  'Sausage Party',
#  'Skin Wars',
#  'Girlboss',
#  '13 Reasons Why',
#  'Felipe Neto: My Life Makes No Sense',
#  'Cheer Squad',
#  'Lost',
#  'Weeds',
#  'The Tudors',
#  "Grey's Anatomy",
#  'Lie to Me',
#  'Prison Break',
#  'Gossip Girl',
#  'Glee',
#  'The Vampire Diaries',
#  'The Secret Life of the American Teenager',
#  'Drop Dead Diva',
#  'Gilmore Girls',
#  'Charmed',
#  'White Collar',
#  'House of Cards',
#  'Pretty Little Liars',
#  'The Killing',
#  'Shameless (U.S.)',
#  'Hart of Dixie',
#  'Once Upon a Time',
#  'Scandal',
#  'The Client List',
#  'Unconditional',
#  'Bates Motel',
#  'The Blacklist',
#  'The Fosters',
#  'Reign',
#  'The Originals',
#  'The 100',
#  'Witches of East End',
#  'Bitten',
#  'London Has Fallen',
#  "Marvel's Jessica Jones",
#  'Bloodline',
#  'Grace and Frankie',
#  'Velvet',
#  'How to Get Away with Murder',
#  'The Crown',
#  'Jane The Virgin',
#  'Kurt Seyit & Sura',
#  'The Returned',
#  'The Girl in the Book',
#  'Quantico',
#  'Life in Pieces',
#  'Ingobernable',
#  'Girlboss',
#  '13 Reasons Why',
#  'MerlÌ?',
#  'Greenleaf',
#  '100 Metros',
#  'Bones',
#  'Dexter',
#  'Leverage',
#  "Grey's Anatomy",
#  'Lie to Me',
#  'Prison Break',
#  'NCIS',
#  'Burn Notice',
#  'Breaking Bad',
#  'Criminal Minds',
#  'White Collar',
#  'Luther',
#  'Hawaii Five-0',
#  'House of Cards',
#  'Last Man Standing',
#  'Revenge',
#  'Person of Interest',
#  'Scandal',
#  'Touch',
#  'Sherlock',
#  'Breakout Kings',
#  'The Client List',
#  'Arrow',
#  'The Following',
#  'Drugs, Inc.',
#  'Longmire',
#  'Ripper Street',
#  'The Fall',
#  'Death in Paradise',
#  "Marvel's Agents of S.H.I.E.L.D.",
#  'Crossing Lines',
#  'London Has Fallen',
#  'Halt and Catch Fire',
#  "Marvel's Iron Fist",
#  'The Honorable Woman',
#  'Transporter: The Series',
#  'Gotham',
#  'Better Call Saul',
#  'How to Get Away with Murder',
#  'Narcos',
#  'American Odyssey',
#  'Aquarius',
#  'Hap and Leonard',
#  'Rosewood',
#  'Quantico',
#  'Limitless',
#  'Travelers',
#  'The Doctor Blake Mysteries',
#  'I.T',
#  'Bordertown',
#  'The Office (U.S.)',
#  "Grey's Anatomy",
#  'Law & Order: Special Victims Unit',
#  'Lie to Me',
#  'Prison Break',
#  '90210',
#  'Gossip Girl',
#  'How I Met Your Mother',
#  'Parks and Recreation',
#  'The Vampire Diaries',
#  'Criminal Minds',
#  'Friends',
#  'The West Wing',
#  'Parenthood',
#  'White Collar',
#  'Blue Bloods',
#  'House of Cards',
#  'Pretty Little Liars',
#  'The Killing',
#  'Shameless (U.S.)',
#  'New Girl',
#  'Revenge',
#  'Person of Interest',
#  'Once Upon a Time',
#  'Scandal',
#  'Forensic Files',
#  'Sherlock',
#  'The Client List',
#  'Orange Is the New Black',
#  'Rectify',
#  'Black Mirror',
#  'Bates Motel',
#  'The Fall',
#  'The Blacklist',
#  'Being Mary Jane: The Series',
#  'American Crime',
#  'Madam Secretary',
#  'Sense8',
#  'Scream',
#  'Rosewood',
#  'The Great British Baking Show',
#  'Quantico',
#  'Limitless',
#  'American Crime Story: The People v. O.J. Simpson',
#  'Santa Clarita Diet',
#  'No Tomorrow',
#  'Girlboss',
#  '13 Reasons Why',
#  'The Doctor Blake Mysteries',
#  'Greenleaf',
#  'The Nightmare Before Christmas',
#  'Scooby-Doo',
#  'Chicken Little',
#  'Teenage Mutant Ninja Turtles',
#  'Star Wars: The Clone Wars',
#  'Coraline',
#  'The Smurfs and the Magic Flute',
#  "We're Back! A Dinosaur's Story",
#  'Thomas & Friends: Thomas & the Runaway Kite',
#  'Dino Squad',
#  "Cars Toons: Mater's Tall Tales",
#  'LeapFrog: The Amazing Alphabet Amusement Park',
#  'Star Wars: The Clone Wars',
#  'Phineas and Ferb',
#  'The Batman',
#  'Justice League',
#  'Justice League Unlimited',
#  'Mighty Morphin Power Rangers',
#  'Young Justice',
#  'The Super Mario Bros. Super Show!',
#  'Power Rangers Zeo',
#  "Oscar's Oasis",
#  'Transformers Prime',
#  'The Adventures of Chuck & Friends',
#  'Transformers: Rescue Bots',
#  'Thomas & Friends: King of the Railway',
#  'LEGO: Marvel Super Heroes: Maximum Overload',
#  'Max Steel',
#  'Transformers Prime Beast Hunters: Predacons Rising',
#  'Agent F.O.X.',
#  'VeggieTales in the House',
#  'Thunder and the House Of Magic',
#  'All Hail King Julien',
#  'Kong: King of the Apes',
#  'Marvel Super Hero Adventures: Frost Fight!',
#  'Slugterra: Slug Fu Showdown',
#  'Dinotrux',
#  "Edgar Rice Burroughs' Tarzan and Jane",
#  'Lego DC Comics: Batman Be-Leaguered',
#  'Trollhunters',
#  'Power Rangers Dino Charge',
#  'Bunks',
#  'The Jungle Book',
#  'The Angry Birds Movie',
#  'The Secret Life of Pets',
#  'The Furchester Hotel',
#  "Marvel's Hulk: Where Monsters Dwell",
#  'Angry Birds',
#  'Talking Tom and Friends',
#  'Nexo Knights',
#  'The Nightmare Before Christmas',
#  'An Extremely Goofy Movie',
#  'Scooby-Doo',
#  'The Iron Giant',
#  'Star Wars: The Clone Wars',
#  "Cars Toons: Mater's Tall Tales",
#  'The Batman',
#  'Justice League',
#  'Justice League Unlimited',
#  'The Cat in the Hat Knows a Lot About That!',
#  'Mighty Morphin Power Rangers',
#  'Bob the Builder',
#  'Beyblade: Metal Fusion',
#  'Ninja Turtles: The Next Mutation',
#  'Transformers Prime',
#  'DreamWorks Kung Fu Panda Awesome Secrets',
#  'LEGO Ninjago: Masters of Spinjitzu',
#  'Transformers: Rescue Bots',
#  'Goosebumps',
#  'LEGO Ninjago: Masters of Spinjitzu: Way of the Ninja',
#  'Super Buddies',
#  'Tad: The Lost Explorer',
#  'PokÌ©mon: Indigo League',
#  'Ratchet and Clank',
#  'Pac-Man and the Ghostly Adventures',
#  'Iron Man & Captain America: Heroes United',
#  'Power Rangers Super Megaforce',
#  'Chuggington',
#  'All Hail King Julien',
#  'The Adventures of Puss in Boots',
#  'Kong: King of the Apes',
#  'Marvel Super Hero Adventures: Frost Fight!',
#  'Some Assembly Required',
#  'Dinotrux',
#  "Edgar Rice Burroughs' Tarzan and Jane",
#  'Kulipari: An Army of Frogs',
#  'Transformers: Robots in Disguise',
#  'Robocar Poli',
#  'LEGO Bionicle: The Journey to One',
#  'Lego DC Comics: Batman Be-Leaguered',
#  'Voltron: Legendary Defender',
#  'Trollhunters',
#  'Buddy Thunderstruck',
#  'Power Rangers Dino Charge',
#  'PokÌ©mon: XY',
#  'Power Rangers Dino Super Charge',
#  'The Deep',
#  'Skylanders Academy',
#  "Marvel's Hulk: Where Monsters Dwell",
#  'Growing Up Wild',
#  'The Little Rascals',
#  'Flubber',
#  'Tarzan',
#  "The Emperor's New Groove",
#  'Scooby-Doo',
#  'Lilo & Stitch',
#  'Scooby-Doo 2: Monsters Unleashed',
#  'The Three Musketeers',
#  "Mickey's Twice Upon a Christmas",
#  'The Pacifier',
#  'Chicken Little',
#  'Teenage Mutant Ninja Turtles',
#  'Bee Movie',
#  'Kung Fu Panda',
#  'Coraline',
#  "Cars Toons: Mater's Tall Tales",
#  'Phineas and Ferb',
#  'Super Why!',
#  'Jessie',
#  'Disney Animation Collection: Vol. 1: Mickey and the Beanstalk',
#  'Lab Rats',
#  'Masha and the Bear',
#  'Pocoyo',
#  'Home',
#  'Chuggington',
#  'Octonauts',
#  'Dragons: Race to the Edge',
#  'Mother Goose Club',
#  'Little Einsteins',
#  'Hotel Transylvania 2',
#  'Dawn of the Croods',
#  'Dinotrux',
#  'Goosebumps',
#  'Kung Fu Panda 3',
#  'Zootopia',
#  'The Jungle Book',
#  'Home: Adventures with Tip & Oh',
#  'Open Season: Scared Silly',
#  'The Land Before Time XIV: Journey of the Brave',
#  'The Angry Birds Movie',
#  'Alice Through the Looking Glass',
#  'Finding Dory',
#  'The Secret Life of Pets',
#  'Ask the StoryBots',
#  'The Furchester Hotel',
#  'Goldie & Bear',
#  'Little Baby Bum: Nursery Rhyme Friends',
#  'Angry Birds',
#  'Tayo the Little Bus',
#  'Talking Tom and Friends',
#  'The Little Rascals',
#  'Antz',
#  'Tarzan',
#  'An Extremely Goofy Movie',
#  'Chicken Run',
#  "The Emperor's New Groove",
#  'Lilo & Stitch',
#  'Spy Kids 3: Game Over',
#  'Annie',
#  'Mulan 2',
#  'Chicken Little',
#  'Lilo & Stitch 2: Stitch Has A Glitch',
#  'Teenage Mutant Ninja Turtles',
#  'Bee Movie',
#  'Kung Fu Panda',
#  "Cars Toons: Mater's Tall Tales",
#  'Super Why!',
#  "DreamWorks Shrek's Swamp Stories",
#  'Beverly Hills Chihuahua 3: Viva La Fiesta!',
#  'DreamWorks Spooky Stories: Volume 2',
#  'The Magic School Bus',
#  'Goosebumps',
#  'Sammy 2',
#  'Disney Animation Collection: Vol. 1: Mickey and the Beanstalk',
#  'Masha and the Bear',
#  'Pocoyo',
#  'Sofia the First',
#  'Barbie Life in the Dreamhouse',
#  'Paddington',
#  'Larva',
#  'Sid the Science Kid',
#  'Chuggington',
#  'All Hail King Julien',
#  'Octonauts',
#  'Minions',
#  'Dragons: Race to the Edge',
#  'Little Einsteins',
#  'Hotel Transylvania 2',
#  'Dinotrux',
#  'The Little Prince',
#  'Word Party',
#  'Zootopia',
#  'The Jungle Book',
#  'Home: Adventures with Tip & Oh',
#  'Open Season: Scared Silly',
#  'The Angry Birds Movie',
#  'Finding Dory',
#  'The Secret Life of Pets',
#  'Goldie & Bear',
#  'Talking Tom and Friends',
#  'Cool Runnings',
#  'Homeward Bound: The Incredible Journey',
#  'The Little Rascals',
#  'Anastasia',
#  'Tarzan',
#  "The Emperor's New Groove",
#  'Scooby-Doo',
#  'Lilo & Stitch',
#  'Missione Hamburger',
#  'Chicken Little',
#  'Curious George',
#  'Bee Movie',
#  'Kung Fu Panda',
#  'Coraline',
#  "Cars Toons: Mater's Tall Tales",
#  'Super Why!',
#  'Jessie',
#  'Secret of the Wings',
#  'The Magic School Bus',
#  'Sammy 2',
#  'Masha and the Bear',
#  'Sofia the First',
#  'Barbie Life in the Dreamhouse',
#  'Clifford the Big Red Dog',
#  'Home',
#  'Paddington',
#  'Chuggington',
#  'Octonauts',
#  'Minions',
#  'Dragons: Race to the Edge',
#  'Little Einsteins',
#  'Hotel Transylvania 2',
#  'Dinotrux',
#  'Walt Disney Animation Studios Short Films Collection',
#  'Kung Fu Panda 3',
#  "Bunk'd",
#  'Zootopia',
#  'The Jungle Book',
#  'Open Season: Scared Silly',
#  'The Land Before Time XIV: Journey of the Brave',
#  'The Angry Birds Movie',
#  'Alice Through the Looking Glass',
#  'The BFG',
#  'The Secret Life of Pets',
#  "Pete's Dragon",
#  'Kubo and the Two Strings',
#  'Goldie & Bear',
#  'Little Baby Bum: Nursery Rhyme Friends',
#  'Growing Up Wild',
#  'The Real Ghostbusters',
#  'Cool Runnings',
#  'Anastasia',
#  'Antz',
#  'Babe: Pig in the City',
#  'The Prince of Egypt',
#  'Paulie',
#  'Tarzan',
#  'The Road to El Dorado',
#  'Fantasia 2000',
#  'Pocahontas II: Journey to a New World',
#  "The Emperor's New Groove",
#  'Fantasia',
#  'An American Tail',
#  "Pooh's Grand Adventure: The Search for Christopher Robin",
#  'FernGully 2: The Magical Rescue',
#  'Balto 2: Wolf Quest',
#  'Balto',
#  'Back to the Secret Garden',
#  'The Brave Little Toaster Goes to Mars',
#  'The Brave Little Toaster to the Rescue',
#  'An American Tail: The Mystery of the Night Monster',
#  'An American Tail: Fievel Goes West',
#  'The Last Unicorn',
#  'The Iron Giant',
#  'Brother Bear 2',
#  'The Fox and the Hound 2',
#  'The Smurfs and the Magic Flute',
#  'Jetsons: The Movie',
#  "We're Back! A Dinosaur's Story",
#  'A Monster in Paris',
#  'The Gruffalo',
#  'DreamWorks How to Train Your Dragon Legends',
#  'Ernest & Celestine',
#  'The Magic School Bus',
#  'Animaniacs',
#  'Disney Animation Collection: Vol. 4: The Tortoise and the Hare',
#  'PopPixie',
#  'Jack and the Cuckoo-Clock Heart',
#  'The Pirate Fairy',
#  'Axel: The Biggest Little Hero',
#  'The Adventures of Figaro Pho',
#  'The Boxcar Children',
#  'Pet Pals in Windland',
#  'Walt Disney Animation Studios Short Films Collection',
#  'Alpha and Omega: Dino Digs',
#  'Alice Through the Looking Glass',
#  'Quackerz',
#  'Hatched',
#  'Blinky Bill: The Movie',
#  'The Real Ghostbusters',
#  'Flubber',
#  'Anastasia',
#  'An Extremely Goofy Movie',
#  'An American Tail',
#  'Scooby-Doo',
#  'FernGully: The Last Rainforest',
#  'Balto 2: Wolf Quest',
#  'Balto',
#  'The Lizzie McGuire Movie',
#  'The Brave Little Toaster Goes to Mars',
#  'The Brave Little Toaster to the Rescue',
#  'Recess: Taking the Fifth Grade',
#  'An American Tail: The Mystery of the Night Monster',
#  'An American Tail: Fievel Goes West',
#  'The Iron Giant',
#  'The Very Hungry Caterpillar and Other Stories',
#  'The Hero of Color City',
#  'Dino Squad',
#  'The Little Engine That Could',
#  'Delhi Safari',
#  'Ninja Turtles: The Next Mutation',
#  'Pound Puppies',
#  'Sammy 2',
#  'Monster Math Squad',
#  'Care Bears: Welcome to Care-a-Lot',
#  'Clifford the Big Red Dog',
#  "Clifford's Puppy Days",
#  'Axel: The Biggest Little Hero',
#  'Agent F.O.X.',
#  'Dinosaur King',
#  'Ribbit',
#  'Chuggington',
#  'Rooster Doodle-doo',
#  'Octonauts',
#  'Kong: King of the Apes',
#  'My Animal Friends',
#  'Worms',
#  'Puffin Rock',
#  'Little Einsteins',
#  'Hotel Transylvania 2',
#  'Dinotrux',
#  'The Mr. Peabody and Sherman Show',
#  'Zoobabu',
#  'Alpha and Omega: Dino Digs',
#  'Gon',
#  'Sid the Science Kid: The Movie',
#  'The Land Before Time XIV: Journey of the Brave',
#  'The Secret Life of Pets',
#  'LEGO Jurassic World: The Indominus Escape',
#  'The Real Ghostbusters',
#  'Cool Runnings',
#  'Anastasia',
#  'Antz',
#  'Babe: Pig in the City',
#  'The Prince of Egypt',
#  'Paulie',
#  'Tarzan',
#  'The Road to El Dorado',
#  'Fantasia 2000',
#  'Pocahontas II: Journey to a New World',
#  "The Emperor's New Groove",
#  'Fantasia',
#  'An American Tail',
#  "Pooh's Grand Adventure: The Search for Christopher Robin",
#  'FernGully 2: The Magical Rescue',
#  'Balto 2: Wolf Quest',
#  'Balto',
#  'Back to the Secret Garden',
#  'The Brave Little Toaster Goes to Mars',
#  'The Brave Little Toaster to the Rescue',
#  'An American Tail: The Mystery of the Night Monster',
#  'An American Tail: Fievel Goes West',
#  'The Last Unicorn',
#  'The Iron Giant',
#  'Brother Bear 2',
#  'The Fox and the Hound 2',
#  'The Smurfs and the Magic Flute',
#  'Jetsons: The Movie',
#  "We're Back! A Dinosaur's Story",
#  'A Monster in Paris',
#  'The Gruffalo',
#  'DreamWorks How to Train Your Dragon Legends',
#  'Ernest & Celestine',
#  'The Magic School Bus',
#  'Animaniacs',
#  'Disney Animation Collection: Vol. 4: The Tortoise and the Hare',
#  'PopPixie',
#  'Jack and the Cuckoo-Clock Heart',
#  'The Pirate Fairy',
#  'Axel: The Biggest Little Hero',
#  'The Adventures of Figaro Pho',
#  'The Boxcar Children',
#  'Pet Pals in Windland',
#  'Walt Disney Animation Studios Short Films Collection',
#  'Alpha and Omega: Dino Digs',
#  'Alice Through the Looking Glass',
#  'Quackerz',
#  'Hatched',
#  'Blinky Bill: The Movie',
#  'The Real Ghostbusters',
#  'Cool Runnings',
#  'Homeward Bound: The Incredible Journey',
#  'Anastasia',
#  'Antz',
#  'Babe: Pig in the City',
#  'The Road to El Dorado',
#  'Fantasia 2000',
#  'Fantasia',
#  'Harry and the Hendersons',
#  "Pooh's Grand Adventure: The Search for Christopher Robin",
#  'Cats & Dogs',
#  'Atlantis: The Lost Empire',
#  'FernGully: The Last Rainforest',
#  'Balto 2: Wolf Quest',
#  'Balto',
#  'Back to the Secret Garden',
#  'Tarzan & Jane',
#  "Atlantis: Milo's Return",
#  'The Brave Little Toaster Goes to Mars',
#  'The Brave Little Toaster to the Rescue',
#  'Annie',
#  'Recess: Taking the Fifth Grade',
#  'An American Tail: The Mystery of the Night Monster',
#  'Batched',
#  'An American Tail: Fievel Goes West',
#  'Winnie the Pooh: Springtime with Roo',
#  'The Last Unicorn',
#  'The Iron Giant',
#  'Mulan 2',
#  "Pooh's Heffalump Movie",
#  "Kronk's New Groove",
#  'Corpse Bride',
#  'Brother Bear 2',
#  'The Smurfs and the Magic Flute',
#  'Jetsons: The Movie',
#  "We're Back! A Dinosaur's Story",
#  'Ernest & Celestine',
#  'Animaniacs',
#  'Disney Animation Collection: Vol. 1: Mickey and the Beanstalk',
#  'Disney Animation Collection: Vol. 2: Three Little Pigs',
#  'Disney Animation Collection: Vol. 4: The Tortoise and the Hare',
#  'The Pirate Fairy',
#  'Underdogs',
#  'The Boxcar Children',
#  'Ribbit',
#  'Yellowbird',
#  'Octonauts',
#  'The Land Before Time XIV: Journey of the Brave',
#  'Quackerz',
#  'Growing Up Wild',
#  'Cool Runnings',
#  'Mr. Magoo',
#  'Flubber',
#  'Anastasia',
#  'Antz',
#  'Babe: Pig in the City',
#  'Paulie',
#  'The Road to El Dorado',
#  'Air Bud: World Pup',
#  'An American Tail',
#  'Harry and the Hendersons',
#  'Cats & Dogs',
#  "Baby's Day Out",
#  'Balto 2: Wolf Quest',
#  'Balto',
#  'Back to the Secret Garden',
#  'Blank Check',
#  'Heavyweights',
#  'Inspector Gadget 2',
#  'Air Bud: Spikes Back',
#  'Annie',
#  'An American Tail: Fievel Goes West',
#  'D2: The Mighty Ducks',
#  'Honey, I Shrunk the Kids',
#  'The Iron Giant',
#  'The Fox and the Hound 2',
#  'Air Buddies',
#  'Dr. Dolittle: Tail to the Chief',
#  'Flicka 2',
#  'H2O: Just Add Water',
#  'The Gruffalo',
#  'Dolphin Tale',
#  'Pound Puppies',
#  'Beverly Hills Chihuahua 3: Viva La Fiesta!',
#  'The Magic School Bus',
#  'Step Dogs',
#  'PokÌ©mon: Indigo League',
#  'Mia and Me',
#  'Paddington',
#  'Russell Madness',
#  'My Animal Friends',
#  'Dawn of the Croods',
#  'Alpha and Omega: Dino Digs',
#  'Wiener Dog Internationals',
#  'Pup Star',
#  'The BFG',
#  'The Secret Life of Pets',
#  'Precious Puppies',
#  'Beary Tales',
#  'Growing Up Wild',
#  ...]

# %%
len(matched_netflix_titles)
# Out:
# 792521319

# %% [markdown]
# # Prepare engine and send data to mysql

# %%
# Setting up connection to mysql workbench
connection_string = "root:<enter your password>@localhost/podcasts_db?charset=utf8"
engine = create_engine(f'mysql://{connection_string}')

# %%
# Display table names in data base, testing connection
engine.table_names()

# %%
# Send data frames into mysql
episodes_final_sorted.to_sql(name='episodes', con=engine, if_exists='append', index=True)

# %%
# Send data frames into mysql
podcast_tvfilm_a.to_sql(name='podcasts', con=engine, if_exists='append', index=True)
